# %%
# !pip install psycopg2-binary
# !pip install pandas
# !pip install faker
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.8.6-cp39-cp39-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 5.3 MB/s eta 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.8.6
# Collecting pandas
#   Downloading pandas-1.2.4-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas) (2021.1)
# Collecting numpy>=1.16.5
#   Downloading numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 53.5 MB/s eta 0:00:01    |███████████████▏                | 7.3 MB 53.5 MB/s eta 0:00:01     |██████████████████████          | 10.5 MB 53.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.20.3 pandas-1.2.4
# Collecting faker
#   Downloading Faker-8.2.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.9 MB/s eta 0:00:01     |████████████████████            | 727 kB 4.9 MB/s eta 0:00:01
# Collecting text-unidecode==1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 4.9 MB/s eta 0:00:011
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.9/site-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: text-unidecode, faker
# Successfully installed faker-8.2.1 text-unidecode-1.3

# %%
import psycopg2

# %%
import pandas as pd

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine

# %% [markdown]
# # link the database

# %%
POSTGRES_ADDRESS = '172.18.0.6'

# %%
POSTGRES_PORT = '5432'

# %%
POSTGRES_USERNAME = 'me'

# %%
POSTGRES_PASSWORD = '1234'

# %%
POSTGRES_DBNAME = 'testDB'

# %%
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'.format(username=POSTGRES_USERNAME, password=POSTGRES_PASSWORD, ipaddress=POSTGRES_ADDRESS, port=POSTGRES_PORT, dbname=POSTGRES_DBNAME))

# %%
engine = create_engine(postgres_str)

# %% [markdown]
# # check the names of tables

# %%
engine.table_names()
# Out:
# <ipython-input-128-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# []

# %% [markdown]
# # delete tables

# %%
engine.execute('''DROP TABLE "trusted_informants", "new_informants" , "processed_informants" ;''')

# %% [markdown]
# # creat a fake list of trusted informants

# %%
from faker import Faker

# %%
fake = Faker()

# %%
import csv
output=open('trusted_informants.csv', 'w')
fake=Faker()
header=['name', 'age', 'city']
mywriter=csv.writer(output)
mywriter.writerow(header)
for r in range(100):
    row=[fake.name(), fake.random_int(min=18, max=80, step=1), fake.city()]
    mywriter.writerow(row)

output.close()

# %% [markdown]
# # update the trusted informants tabel

# %%
df = pd.read_csv('trusted_informants.csv')

# %%
df.head()
# Out:
#                name  age              city
# 0        Eric Smith   67         Jasontown
# 1      Justin Banks   23      Patrickshire
# 2     Courtney Hale   43        Port Wendy
# 3  Frances Mitchell   35  Lake Roberthaven
# 4        Colin West   67      New Jillbury

# %%
df.to_sql('trusted_informants', engine, if_exists='replace', index=False)

# %% [markdown]
# # creat a fake list of  new informants

# %%
import csv
output=open('new_informants.csv', 'w')
fake=Faker()
header=['name', 'age', 'city']
mywriter=csv.writer(output)
mywriter.writerow(header)
for r in range(100):
    row=[fake.name(), fake.random_int(min=18, max=80, step=1), fake.city()]
    mywriter.writerow(row)

output.close()

# %% [markdown]
# # stop !#
# enter the semilarity now !

# %% [markdown]
# # update the new_informants table

# %%
df = pd.read_csv('new_informants.csv')

# %%
df.head()
# Out:
#             name  age          city
# 0     Eric Smith   67     Jasontown
# 1   Justin Banks   23  Patrickshire
# 2  Courtney Hale   43    Port Wendy
# 3     Erica Pena   42    Smithhaven
# 4  Bonnie Nguyen   25      Wolfside

# %%
df.to_sql('new_informants', engine, if_exists='replace', index=False)

# %% [markdown]
# # the 'Automated' comparison

# %%
df=pd.read_sql_query('''


SELECT * 
FROM new_informants 
inner join trusted_informants on trusted_informants.name =  new_informants.name trusted_informants.age =  new_informants.age
trusted_informants.city =  new_informants.name
''', engine)
df
# Out:
#                name  age          city              name  age          city
# 0        Eric Smith   67     Jasontown        Eric Smith   67     Jasontown
# 1      Justin Banks   23  Patrickshire      Justin Banks   23  Patrickshire
# 2     Courtney Hale   43    Port Wendy     Courtney Hale   43    Port Wendy
# 3  Brittany Ramirez   68     East Paul  Brittany Ramirez   69     Garciaton

# %% [markdown]
# # store the processed_transformants

# %%
df.to_sql('processed_informants', engine, if_exists='replace', index=False)

# %%
df=pd.read_sql_query('''SELECT * FROM processed_informants ; ''', engine)
df
# Out:
#                name  age          city
# 0        Eric Smith   67     Jasontown
# 1      Justin Banks   23  Patrickshire
# 2     Courtney Hale   43    Port Wendy
# 3  Brittany Ramirez   69     Garciaton

# %% [markdown]
# # to be dealt with later

# %%
df = pd.read_csv('new_informants.csv')
df.to_sql('new_informants', engine, if_exists='replace', index=False)
df=pd.read_sql_query('''SELECT * FROM new_informants limit 5; ''', engine)
df
# Out:
#                name  age           city
# 0      Shelia Lopez   45       Woodston
# 1     Heather Brown   48  Blackburntown
# 2  Jonathan Michael   79       Ryanbury
# 3     Morgan Howard   54  East Karenton
# 4    Nina Gutierrez   74  Alexanderberg
